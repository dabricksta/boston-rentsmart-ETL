# %%
import pandas as pd
import numpy as np
import os
import matplotlib as mpl
import random
import pipe

# %% [markdown]
# Let's test out all the fun examples in the Boston.gov Data API

# %%
import json
import urllib.request
url = 'https://data.boston.gov/api/3/action/datastore_search?resource_id=dc615ff7-2ff3-416a-922b-f0f334f085d0&limit=5&q=title:jones'  
fileobj = urllib.request.urlopen(url)
response_dict = json.loads(fileobj.read())
print(response_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [1], line 4
#       2 import urllib.request
#       3 url = 'https://data.boston.gov/api/3/action/datastore_search?resource_id=dc615ff7-2ff3-416a-922b-f0f334f085d0&limit=5&q=title:jones'
# ----> 4 fileobj = urllib.request.urlopen(url)
#       5 response_dict = json.loads(fileobj.read())
#       6 print(response_dict)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:213, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     211     opener = build_opener(https_handler)
#     212 elif _opener is None:
# --> 213     _opener = opener = build_opener()
#     214 else:
#     215     opener = _opener
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:597, in build_opener(*handlers)
#     594     default_classes.remove(klass)
# ...

# %%
"1850-to-1899.csv'
'1900-to-1919.csv'
'1920-to-1929.csv'
'1930-to-1939.csv'
'1940-to-1949.csv'
'1950-to-1959.csv'
'1960-to-1969.csv'
'1970-to-1979.csv'
'1980-to-1999.csv'
'2016-to-2022.csv'


sample_1800 = pd.read_csv(
    '1800-to-1849.csv',
    header=0, 
    skiprows=lambda i: i>0 and random.random() > .01
    )

sample_1800.head()
# Out:
#    rs_prop_sam_id  rs_prop_prim_sam_id rs_prop_full_address  \
# 0          227292                50325      13 Dwight St #2
# 1           98882               167936    8 Mount Vernon St
# 2             281                  281           7 Acorn St
# 3           93998                93998         6 Melrose St
# 4           36093                36093        9 Columbus Sq
#
#    rs_prop_street_number rs_prop_full_street_name  rs_prop_unit_number  \
# 0                     13                Dwight St                  2.0
# 1                      8          Mount Vernon St                  NaN
# 2                      7                 Acorn St                  NaN
# 3                      6               Melrose St                  NaN
# 4                      9              Columbus Sq                  NaN
#
#    rs_prop_zip_code rs_prop_mailing_neighborhood  rs_prop_long  rs_prop_lat  \
# 0              2118                      Roxbury     -71.06813     42.34420
# ...

# %%
'1900-to-1919.csv'
'1920-to-1929.csv'
'1930-to-1939.csv'
'1940-to-1949.csv'
'1950-to-1959.csv'
'1960-to-1969.csv'
'1970-to-1979.csv'
'1980-to-1999.csv'
'2016-to-2022.csv'
ct = 0
with open('1850-to-1899.csv') as f:
    len(count.fields(f))

# sample_1850 = pd.read_csv(
#     '1850-to-1899.csv'
#     , header = 0
#     , nrows = 10
#     )

# sample_1850.head()

# %%
'1920-to-1929.csv'
'1930-to-1939.csv'
'1940-to-1949.csv'
'1950-to-1959.csv'
'1960-to-1969.csv'
'1970-to-1979.csv'
'1980-to-1999.csv'
'2016-to-2022.csv'


sample_1900 = pd.read_csv(
    '1900-to-1919.csv'
    , header = 0
    , nrows = 10
    )

sample_1900.head()
# Out:
#    rs_prop_sam_id  rs_prop_prim_sam_id  rs_prop_full_address  \
# 0           42986                42986        243 Cornell St
# 1           97889                97889         27 Moseley St
# 2          107474               107474           205 Park St
# 3          422070               422070  10R Spring Garden St
# 4          122952               122952          4 Sargent St
#
#   rs_prop_street_number rs_prop_full_street_name  rs_prop_unit_number  \
# 0                   243               Cornell St                  NaN
# 1                    27               Moseley St                  NaN
# 2                   205                  Park St                  NaN
# 3                   10R         Spring Garden St                  NaN
# 4                     4               Sargent St                  NaN
#
#    rs_prop_zip_code rs_prop_mailing_neighborhood  rs_prop_long  rs_prop_lat  \
# 0              2131                   Roslindale    -71.136400     42.28031
# ...

# %%
'1930-to-1939.csv'
'1940-to-1949.csv'
'1950-to-1959.csv'
'1960-to-1969.csv'
'1970-to-1979.csv'
'1980-to-1999.csv'
'2016-to-2022.csv'


sample_1920 = pd.read_csv(
    '1920-to-1929.csv'
    , header = 0
    , nrows = 10
    ).filter(regex = 'rs_*')

sample_1920.head()
# Out:
#    rs_prop_sam_id  rs_prop_prim_sam_id   rs_prop_full_address  \
# 0          111444               111444         5-9 Pomeroy St
# 1           58728                58728         32 Fletcher St
# 2           62202                62202  105-107 Gallivan Blvd
# 3          150449               150449      54 Wilmington Ave
# 4          150261               150261          192 Willow St
#
#   rs_prop_street_number rs_prop_full_street_name  rs_prop_unit_number  \
# 0                   5-9               Pomeroy St                  NaN
# 1                    32              Fletcher St                  NaN
# 2               105-107            Gallivan Blvd                  NaN
# 3                    54           Wilmington Ave                  NaN
# 4                   192                Willow St                  NaN
#
#    rs_prop_zip_code rs_prop_mailing_neighborhood  rs_prop_long  rs_prop_lat  \
# 0              2134                      Allston    -71.141129    42.353559
# ...

# %%
'1940-to-1949.csv'
'1950-to-1959.csv'
'1960-to-1969.csv'
'1970-to-1979.csv'
'1980-to-1999.csv'
'2016-to-2022.csv'


sample_1930 = pd.read_csv(
    '1930-to-1939.csv'
    , header = 0
    , nrows = 10
    ).filter(regex = 'rs_*')

sample_1930.head()
# Out:
#    rs_prop_sam_id  rs_prop_prim_sam_id rs_prop_full_address  \
# 0          119280               119280         11 Roxton St
# 1           59618                59618        169 Foster St
# 2          100126               100126             215 N St
# 3           14422                14422   103-105 Bennett St
# 4          121143               121143  77 Saint Gregory St
#
#   rs_prop_street_number rs_prop_full_street_name  rs_prop_unit_number  \
# 0                    11                Roxton St                  NaN
# 1                   169                Foster St                  NaN
# 2                   215                     N St                  NaN
# 3               103-105               Bennett St                  NaN
# 4                    77         Saint Gregory St                  NaN
#
#    rs_prop_zip_code rs_prop_mailing_neighborhood  rs_prop_long  rs_prop_lat  \
# 0              2121                   Dorchester    -71.080360    42.298100
# ...

# %%
'1950-to-1959.csv'
'1960-to-1969.csv'
'1970-to-1979.csv'
'1980-to-1999.csv'
'2016-to-2022.csv'


sample_1940 = pd.read_csv(
    '1940-to-1949.csv'
    , header = 0
    , nrows = 10
    ).filter(regex = 'rs_*')

sample_1940.head()
sample_1940.dtypes
# Out:
# rs_prop_sam_id                    int64
# rs_prop_prim_sam_id               int64
# rs_prop_full_address             object
# rs_prop_street_number             int64
# rs_prop_full_street_name         object
# rs_prop_unit_number             float64
# rs_prop_zip_code                  int64
# rs_prop_mailing_neighborhood     object
# rs_prop_long                    float64
# rs_prop_lat                     float64
# rs_prop_pid                       int64
# rs_prop_lu                       object
# rs_prop_owner                    object
# rs_prop_yr_built                  int64
# rs_prop_yr_remod                float64
# rs_prop_living_area               int64
# rs_prop_bdrms                   float64
# rs_prop_full_bth                float64
# rs_prop_half_bth                float64
# dtype: object

# %%
'1950-to-1959.csv'
'1960-to-1969.csv'
'1970-to-1979.csv'
'1980-to-1999.csv'
'2016-to-2022.csv'


sample_2016 = pd.read_csv(
    '2016-to-2022.csv'
    , header = 0
    , nrows = 10
    )

# sample_2016.head()
sample_2016.dtypes
# sample_2016.info
# Out:
# date               object
# violation_type     object
# description        object
# address            object
# neighborhood       object
# zip_code            int64
# parcel              int64
# owner              object
# year built          int64
# year remodeled    float64
# property_type      object
# latitude          float64
# longitude         float64
# dtype: object

# %%
############################################################ Work with first file ############################################################
df1 = pd.read_csv('1700-to-1799.csv').filter(regex = 'rs_*')

file_names = (
    # '1700-to-1799.csv',
    '1800-to-1849.csv'
    , '1850-to-1899.csv'
    , '1900-to-1919.csv'
    , '1920-to-1929.csv'
    , '1930-to-1939.csv'
    , '1940-to-1949.csv'
    , '1950-to-1959.csv'
    , '1960-to-1969.csv'
    , '1970-to-1979.csv'
    , '1980-to-1999.csv'
    , '2000-to-2019.csv'
    # , '2016-to-2022.csv'
    )

# with open('2016-to-2022.csv') as f:
#     for line in f:
#         sample_foo(line.split(","))
    
for n in file_names:
    df2 = pd.read_csv(n).filter(regex = 'rs_*')
    df1 = pd.concat([df1, df2], ignore_index=True)

############################################################ Export ############################################################
# df1.to_csv('all_rentsmart.csv')
df1.to_parquet('all_rentsmart.parquet.gzip', compression = gzip)

# %%
# So I'm super smart and did not realize that the only actual violation data is in the 2016-to-2022.csv file
# All of the rest are just property records partitioned on date of construction(?)
# Therefore let's just work with that one, beautifully complete CSV
import pandas as pd

############################################################ Work with final file ############################################################
df = pd.read_csv('2016-to-2022.csv')


df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df.columns = ['date', 'violation_type', 'description', 'address', 'neighborhood', 'zip_code', 'parcel', 'owner', 'year_built', 'year_remodeled', 'property_type', 'latitude', 'longitude']
# df.astype({'year_built': 'int32', 'year_remodeled': 'int32'})
df.head()

# df.to_csv('2016-to-2022_cleaned.csv')
# Out:
#         date          violation_type                     description  \
# 0 2022-10-03  Enforcement Violations  Overfilling of barrel/dumpster
# 1 2022-10-03  Enforcement Violations     Improper storage trash: res
# 2 2022-10-03  Enforcement Violations     Improper storage trash: res
# 3 2022-10-03  Enforcement Violations  Overfilling of barrel/dumpster
# 4 2022-10-03  Enforcement Violations     Improper storage trash: res
#
#                      address neighborhood  zip_code     parcel  \
# 0      324 Newbury St, 02115       Boston      2115  503060000
# 1        16 Temple St, 02114       Boston      2114  300023000
# 2    9-11 Pinckney St, 02114       Boston      2114  501896000
# 3       81 Newbury St, 02116       Boston      2116  501286000
# 4  416-418 Hanover St, 02113       Boston      2113  302054000
#
#                           owner  year_built  year_remodeled  \
# 0       JP NEWBURY LLC MASS LLC      1915.0          2012.0
# ...

# %%
df.dtypes
# Out:
# date              datetime64[ns]
# violation_type            object
# description               object
# address                   object
# neighborhood              object
# zip_code                   int64
# parcel                     int64
# owner                     object
# year_built               float64
# year_remodeled           float64
# property_type             object
# latitude                 float64
# longitude                float64
# dtype: object
